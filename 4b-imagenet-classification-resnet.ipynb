# %%
# 4b
from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np

# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet')

# Load an image file that contains an image to be classified
img_path = '/kaggle/input/dog-image/dog_10.jpg'  # Replace with the path to your image
img = image.load_img(img_path, target_size=(224, 224))

# Convert the image to a numpy array
x = image.img_to_array(img)

# Add a batch dimension (since the model expects a batch of images)
x = np.expand_dims(x, axis=0)

# Preprocess the input image for the model
x = preprocess_input(x)

# Predict the class of the image
predictions = model.predict(x)

# Decode the top 3 predictions into human-readable class names
print('Predicted:', decode_predictions(predictions, top=3)[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729271650.101960     104 service.cc:145] XLA service 0x7ab67c0455a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729271650.102046     104 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1729271650.102052     104 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n02105162', 'malinois', 0.8044558), ('n03803284', 'muzzle', 0.050655093), ('n02106662', 'German_shepherd', 0.035840593)]
# I0000 00:00:1729271653.717379     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
